# %% [markdown]
# # Fake News Detection - LSTM
#
# This notebook implements and evaluates the **LSTM (Long Short-Term Memory)** neural network model for fake news detection.

# %%
# Import libraries
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
